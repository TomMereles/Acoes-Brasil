# %% [markdown]
# <a href="https://colab.research.google.com/github/TomMereles/Acoes-Brasil/blob/main/Scraping_acoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
header = {'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'}

url = 'https://br.investing.com/equities/brazil'

request = requests.get(url)

df = pd.read_html(request.text)
df
# Out:
# [    Unnamed: 0                Nome  Último  Máxima  Mínima  Variação    Var%  \
#  0          NaN             Rumo ON    1880    1915    1869       -44  -2,29%
#  1          NaN       Alpargatas PN    1499    1568    1492       -78  -4,95%
#  2          NaN            Ambev ON    1602    1620    1597       -31  -1,90%
#  3          NaN           Arezzo ON    8434    8760    8320      -294  -3,37%
#  4          NaN  Banco do Brasil ON    3520    3596    3502       -83  -2,30%
#  ..         ...                 ...     ...     ...     ...       ...     ...
#  87         NaN        Rede D'Or ON    2917    3055    2901      -154  -5,01%
#  88         NaN    CSN Mineração ON     380     397     378        -1  -0,26%
#  89         NaN            Assaí ON    2038    2051    2003       -16  -0,78%
#  90         NaN           Raizen PN     373     395     371       -17  -4,36%
#  91         NaN        Iguatemi Unt    1831    1882    1822       -61  -3,22%
#
#        Vol.   Hora  Unnamed: 9
# ...

# %%
for i , table in enumerate(df):
    print('================================================================================')
    print(i)
    print(table)
# Out:
# ...
# 0
#     Unnamed: 0                Nome  Último  Máxima  Mínima  Variação    Var%  \
# 0          NaN             Rumo ON    1880    1915    1869       -44  -2,29%
# 1          NaN       Alpargatas PN    1499    1568    1492       -78  -4,95%
# 2          NaN            Ambev ON    1602    1620    1597       -31  -1,90%
# 3          NaN           Arezzo ON    8434    8760    8320      -294  -3,37%
# 4          NaN  Banco do Brasil ON    3520    3596    3502       -83  -2,30%
# ..         ...                 ...     ...     ...     ...       ...     ...
# 87         NaN        Rede D'Or ON    2917    3055    2901      -154  -5,01%
# 88         NaN    CSN Mineração ON     380     397     378        -1  -0,26%
# 89         NaN            Assaí ON    2038    2051    2003       -16  -0,78%
# 90         NaN           Raizen PN     373     395     371       -17  -4,36%
# 91         NaN        Iguatemi Unt    1831    1882    1822       -61  -3,22%
#
#       Vol.   Hora  Unnamed: 9
# ...

# %%
df = pd.DataFrame(df[0])

# %%
df
# Out:
#     Unnamed: 0                Nome  Último  Máxima  Mínima  Variação    Var%  \
# 0          NaN             Rumo ON    1880    1915    1869       -44  -2,29%
# 1          NaN       Alpargatas PN    1499    1568    1492       -78  -4,95%
# 2          NaN            Ambev ON    1602    1620    1597       -31  -1,90%
# 3          NaN           Arezzo ON    8434    8760    8320      -294  -3,37%
# 4          NaN  Banco do Brasil ON    3520    3596    3502       -83  -2,30%
# ..         ...                 ...     ...     ...     ...       ...     ...
# 87         NaN        Rede D'Or ON    2917    3055    2901      -154  -5,01%
# 88         NaN    CSN Mineração ON     380     397     378        -1  -0,26%
# 89         NaN            Assaí ON    2038    2051    2003       -16  -0,78%
# 90         NaN           Raizen PN     373     395     371       -17  -4,36%
# 91         NaN        Iguatemi Unt    1831    1882    1822       -61  -3,22%
#
#       Vol.   Hora  Unnamed: 9
# ...

# %%
df['Último'] = df['Último'] / 100
df['Máxima'] = df['Máxima'] / 100
df['Mínima'] = df['Mínima'] / 100

# %%
df
# Out:
#     Unnamed: 0                Nome  Último  Máxima  Mínima  Variação    Var%  \
# 0          NaN             Rumo ON   18.80   19.15   18.69       -44  -2,29%
# 1          NaN       Alpargatas PN   14.99   15.68   14.92       -78  -4,95%
# 2          NaN            Ambev ON   16.02   16.20   15.97       -31  -1,90%
# 3          NaN           Arezzo ON   84.34   87.60   83.20      -294  -3,37%
# 4          NaN  Banco do Brasil ON   35.20   35.96   35.02       -83  -2,30%
# ..         ...                 ...     ...     ...     ...       ...     ...
# 87         NaN        Rede D'Or ON   29.17   30.55   29.01      -154  -5,01%
# 88         NaN    CSN Mineração ON    3.80    3.97    3.78        -1  -0,26%
# 89         NaN            Assaí ON   20.38   20.51   20.03       -16  -0,78%
# 90         NaN           Raizen PN    3.73    3.95    3.71       -17  -4,36%
# 91         NaN        Iguatemi Unt   18.31   18.82   18.22       -61  -3,22%
#
#       Vol.   Hora  Unnamed: 9
# ...

# %%
df = df.drop(columns = ['Unnamed: 0', 'Unnamed: 9'])

# %%
df
# Out:
#                   Nome  Último  Máxima  Mínima  Variação    Var%    Vol.  \
# 0              Rumo ON   18.80   19.15   18.69       -44  -2,29%   4,96M
# 1        Alpargatas PN   14.99   15.68   14.92       -78  -4,95%   5,16M
# 2             Ambev ON   16.02   16.20   15.97       -31  -1,90%  22,92M
# 3            Arezzo ON   84.34   87.60   83.20      -294  -3,37%   1,26M
# 4   Banco do Brasil ON   35.20   35.96   35.02       -83  -2,30%  10,36M
# ..                 ...     ...     ...     ...       ...     ...     ...
# 87        Rede D'Or ON   29.17   30.55   29.01      -154  -5,01%   2,95M
# 88    CSN Mineração ON    3.80    3.97    3.78        -1  -0,26%   9,37M
# 89            Assaí ON   20.38   20.51   20.03       -16  -0,78%  17,25M
# 90           Raizen PN    3.73    3.95    3.71       -17  -4,36%  14,61M
# 91        Iguatemi Unt   18.31   18.82   18.22       -61  -3,22%   2,13M
#
#      Hora
# 0   05/12
# 1   05/12
# 2   05/12
# 3   05/12
# 4   05/12
# ..    ...
# ...
